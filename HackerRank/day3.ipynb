# %%
a = "qA2"
for i in range(len(a)):
    print(i)
# Out:
# 0
# 1
# 2

# %%
for i,j in enumerate(a):
    # print(i,j).isalpha().isalnum().islower().isupper()
    if j.isalnum():
        print('True')
    elif j.isalpha():
        print('True')
    elif j.isdigit():
        print('True')
    elif j.islower():
        print('True')
    elif j.isupper():
        print('True')
    else:
        print('False')
# Out:
# True
# True
# True

# %%
print(a.isdigit())
# Out:
# False

# %% [markdown]
# `elif means “stop checking after the first True” — but this problem needs ALL checks independently.`
#
# `any() is faster, cleaner, more Pythonic, and exactly what the problem expects.`

# %%
print(any(c.isalnum() for c in a))
print(any(c.isalpha() for c in a))
print(any(c.isdigit() for c in a))
print(any(c.islower() for c in a))
print(any(c.isupper() for c in a))
# Out:
# True
# True
# True
# True
# True

# %% [markdown]
# `Fastest + most memory-efficient solution = single loop + flags + early break`
#
# `if not has_alnum মানে → “এখনো পাওয়া যায়নি, তাই খোঁজা চালাও”`
#
# | Expression  | Result  |
# | ----------- | ------- |
# | `not False` | `True`  |
# | `not True`  | `False` |

# %%
has_alnum = has_alpha = has_digit = has_lower = has_upper = False

for c in a:
    if not has_alnum and c.isalnum():
        has_alnum = True
    if not has_alpha and c.isalpha():
        has_alpha = True
    if not has_digit and c.isdigit():
        has_digit = True
    if not has_lower and c.islower():
        has_lower = True
    if not has_upper and c.isupper():
        has_upper = True

    # Early exit when all are True
    if has_alnum and has_alpha and has_digit and has_lower and has_upper:
        break

print(has_alnum)
print(has_alpha)
print(has_digit)
print(has_lower)
print(has_upper)
# Out:
# True
# True
# True
# True
# True

# %%
for c in a:
    print(c)
# Out:
# q
# A
# 2

# %%
width = 20
print('HackerRank'.ljust(width,'-'))
# Out:
# HackerRank----------

# %%
a = 5 
for i in range(0, len(a)):
    print (a[i::-1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 2
#       1 a = 5
# ----> 2 for i in range(0, len(a)):
#       3     print (a[i::-1])
#
# TypeError: object of type 'int' has no len()

# %%
n = 5

for i in range(1, n + 1):
    print(" " * (n - i), end="")
    
    for j in range(1, i + 1):
        print(j, end="")
        
    for j in range(i - 1, 0, -1):
        print(j, end="")
        
    print()
# Out:
#     1
#    121
#   12321
#  1234321
# 123454321

# %%
n = 5

for i in range(n):
    print(" " * (n - i - 1) + '*' * (2 * i + 1))
# Out:
#     *
#    ***
#   *****
#  *******
# *********

# %%
for i in range(n):
    print(' '*((i+1)+width) + "*"*(2*(n-i)))
    # print(' '*(i+(width-n)) + "H "*(n-i))
# Out:
#                      **********
#                       ********
#                        ******
#                         ****
#                          **

# %%
n = 8

for i in range(n):
    print("* " * (n - i) )
    # print("" * (i) + "* " * (n - i - 1))
# Out:
# * * * * * * * *
# * * * * * * *
# * * * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
n = 8

for i in range(n):
    print(" " * (i) + "* " * (n - i - 1))
    # print(" " * i + "*" * (2 * (n - i) - 1))
# Out:
# * * * * * * *
#  * * * * * *
#   * * * * *
#    * * * *
#     * * *
#      * *
#       *

# %%
n = 8

for i in range(n):
    # print(" " * (n-i) + "* " * (i+1))
    print(" " * (n - i - 1) + "* " * (i + 1))
# Out:
#        *
#       * *
#      * * *
#     * * * *
#    * * * * *
#   * * * * * *
#  * * * * * * *
# * * * * * * * *

# %%
width = 20
print('HackerRank'.ljust(width,'-'))

width = 20
print('HackerRank'.center(width,'-'))

width = 20
print('HackerRank'.rjust(width,'-'))
# Out:
# HackerRank----------
# -----HackerRank-----
# ----------HackerRank

# %%
width = 20
print('HackerRank'.ljust(width,' ') + 'HackerRank'.ljust(width,' '))
# Out:
# HackerRank          HackerRank

# %%
width = 15
print((' ' * 5).center(width, 'H'))

print('HackerRank'.center(width,'-'))
# Out:
# HHHHH     HHHHH
# HHHHH     HHHHH
# HHHHH     HHHHH
# HHHHH     HHHHH
# HHHHH     HHHHH
# ---HackerRank--

# %%
n = 5

for i in range(n):
    print(" " * (n-i-1) + "*" * (2*i+1))
# Out:
#     *
#    ***
#   *****
#  *******
# *********

# %%
n = 5
width = 4*n
for i in range(n):
    print(" " * (n-i-1) + "H" * (2*i+1))

for i in range(n):
    print((' ' * (n-3)).ljust(0, ' ')+(' ' * (n)).center(width, 'H'))

for i in range(n+1):
    if i%2 ==0:
        print((' ' * (n-3)+('H'*(width+1))))

for i in range(n):
    print((' ' * (n-3)).ljust(0, ' ')+(' ' * (n)).center(width, 'H'))

for i in range(n):
    print(' '*((i+1)+width-12) + "H"*(2*(n-i)-1))
# Out:
#     H
#    HHH
#   HHHHH
#  HHHHHHH
# HHHHHHHHH
#   HHHHHHH     HHHHHHHH
#   HHHHHHH     HHHHHHHH
#   HHHHHHH     HHHHHHHH
#   HHHHHHH     HHHHHHHH
#   HHHHHHH     HHHHHHHH
#   HHHHHHHHHHHHHHHHHHHHH
#   HHHHHHHHHHHHHHHHHHHHH
#   HHHHHHHHHHHHHHHHHHHHH
#   HHHHHHH     HHHHHHHH
#   HHHHHHH     HHHHHHHH
#   HHHHHHH     HHHHHHHH
#   HHHHHHH     HHHHHHHH
#   HHHHHHH     HHHHHHHH
#          HHHHHHHHH
#           HHHHHHH
#            HHHHH
#             HHH
#              H

# %%
n = int(input())
thickness = n  # thickness must be odd

# Top Cone
for i in range(thickness):
    print(("H" * i).rjust(thickness - 1) + "H" + ("H" * i).ljust(thickness - 1))

# Top Pillars
for i in range(thickness + 1):
    print(("H" * thickness).center(thickness * 2) +
          ("H" * thickness).center(thickness * 6))

##                                                      -------- Best Code ---------
# Middle Belt
for i in range((thickness + 1) // 2):
    print(("H" * thickness * 5).center(thickness * 6))

# Bottom Pillars
for i in range(thickness + 1):
    print(("H" * thickness).center(thickness * 2) +
          ("H" * thickness).center(thickness * 6))

# Bottom Cone
for i in range(thickness):
    print((("H" * (thickness - i - 1)).rjust(thickness) +
           "H" +
           ("H" * (thickness - i - 1)).ljust(thickness)).rjust(thickness * 6))
# Out:
#     H
#    HHH
#   HHHHH
#  HHHHHHH
# HHHHHHHHH
#   HHHHH               HHHHH
#   HHHHH               HHHHH
#   HHHHH               HHHHH
#   HHHHH               HHHHH
#   HHHHH               HHHHH
#   HHHHH               HHHHH
#   HHHHHHHHHHHHHHHHHHHHHHHHH
#   HHHHHHHHHHHHHHHHHHHHHHHHH
#   HHHHHHHHHHHHHHHHHHHHHHHHH
#   HHHHH               HHHHH
#   HHHHH               HHHHH
#   HHHHH               HHHHH
#   HHHHH               HHHHH
#   HHHHH               HHHHH
#   HHHHH               HHHHH
#                     HHHHHHHHH
#                      HHHHHHH
#                       HHHHH
#                        HHH
#                         H

# %%
n = int(input())
width = 5 * n  # Correct total width

# Top cone
for i in range(n):
    print(("H" * i).rjust(n - 1) + "H" + ("H" * i).ljust(n - 1))

# Top pillars
for i in range(n + 1):
    print(("H" * n).center(width // 3) + ("H" * n).center(width // 3 * 2))

# Middle belt
for i in range((n + 1) // 2):
    print(("H" * (5 * n)).center(width))

# Bottom pillars
for i in range(n + 1):
    print(("H" * n).center(width // 3) + ("H" * n).center(width // 3 * 2))

# Bottom cone
for i in range(n):
    print((("H" * (n - i - 1)).rjust(n) + "H" + ("H" * (n - i - 1)).ljust(n+n)).rjust(width))
# Out:
#     H
#    HHH
#   HHHHH
#  HHHHHHH
# HHHHHHHHH
#  HHHHH       HHHHH
#  HHHHH       HHHHH
#  HHHHH       HHHHH
#  HHHHH       HHHHH
#  HHHHH       HHHHH
#  HHHHH       HHHHH
# HHHHHHHHHHHHHHHHHHHHHHHHH
# HHHHHHHHHHHHHHHHHHHHHHHHH
# HHHHHHHHHHHHHHHHHHHHHHHHH
#  HHHHH       HHHHH
#  HHHHH       HHHHH
#  HHHHH       HHHHH
#  HHHHH       HHHHH
#  HHHHH       HHHHH
#  HHHHH       HHHHH
#           HHHHHHHHH
#            HHHHHHH
#             HHHHH
#              HHH
#               H

# %%
n = 5
width = 6 * n  # total width

# Top cone
for i in range(n):
    print(("H"*i).rjust(n-1,'-') + "H" + ("H"*i).ljust(n-1))

# Top pillars
for i in range(n+1):
    print(("H"*n).center(width//3) + ("H"*n).center(width//3*3,'-'))

# Middle belt
for i in range((n+1)//2):
    print(("H"*5*5).center(5*6,'-'))

# Bottom pillars
for i in range(n+1):
    print(("H"*n).center(width//3,'-') + ("H"*n).center(width//3*3))

# Bottom cone
for i in range(n):
    print((("H"*(n-i-1)).rjust(n) + "H" + ("H"*(n-i-1)).ljust(n)).rjust(width,'-'))
# Out:
# ----H
# ---HHH
# --HHHHH
# -HHHHHHH
# HHHHHHHHH
#   HHHHH   ------------HHHHH-------------
#   HHHHH   ------------HHHHH-------------
#   HHHHH   ------------HHHHH-------------
#   HHHHH   ------------HHHHH-------------
#   HHHHH   ------------HHHHH-------------
#   HHHHH   ------------HHHHH-------------
# --HHHHHHHHHHHHHHHHHHHHHHHHH---
# --HHHHHHHHHHHHHHHHHHHHHHHHH---
# --HHHHHHHHHHHHHHHHHHHHHHHHH---
# --HHHHH---            HHHHH
# --HHHHH---            HHHHH
# --HHHHH---            HHHHH
# --HHHHH---            HHHHH
# --HHHHH---            HHHHH
# --HHHHH---            HHHHH
# ------------------- HHHHHHHHH
# -------------------  HHHHHHH
# -------------------   HHHHH
# -------------------    HHH
# -------------------     H

# %%
n = 5
for i in range(n):
    print(("H"*i).rjust(n-1,'-') + "H" + ("H"*i).ljust(n-1,'-'))
# Out:
# ----H----
# ---HHH---
# --HHHHH--
# -HHHHHHH-
# HHHHHHHHH

# %%
#  Bottom cone
width = 20
for i in range(n):
    print((("H" * (n - i - 1)).rjust(n,'-') + "-" + ("H" * (n - i - 1)).ljust(n,'-')).rjust(width,'-'))
# Out:
# ----------HHHH-HHHH-
# -----------HHH-HHH--
# ------------HH-HH---
# -------------H-H----
# --------------------
