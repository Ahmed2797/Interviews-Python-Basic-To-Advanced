# %% [markdown]
# ## What is an Exception?
#
# An exception is a runtime error that occurs during the execution of a program and interrupts the normal flow unless it is handled.
#
# Exception হলো এমন একটি error যা program চলাকালীন (runtime) ঘটে। যদি এটি handle না করা হয়, তাহলে program বন্ধ হয়ে যায় (crash করে)।
#
# ## why Exception as e?
#
# Interview Answer:
#
# It allows us to inspect or log the actual error message instead of hiding it.
#
# ## Why use try?
#
# To protect code that may raise an exception.
#
# ### else runs only if the try block succeeds.
#
# ## Why use finally?
#
# To execute cleanup code regardless of whether an exception occurred.
#
# The finally block contains code that always executes, whether an exception occurs or not.
#
# It is mainly used for cleanup tasks, such as:
#
#     Closing files
#     Closing database connections
#     Releasing locks
#     Cleaning up resources
#
#                                                       try
#                                                       │
#                                                 ┌─────┴─────┐
#                                                 │           │
#                                             No Error     Error
#                                                 │           │
#                                               else?      except?
#                                                 │           │
#                                                 └─────┬─────┘
#                                                       │
#                                                     finally

# %%
# input = "Ahmed"

try:
    num = int(input())

    print(10 / num)

except ValueError:
    print("Please enter a number.")

except ZeroDivisionError:
    print("Cannot divide by zero.")
# Out:
# Cannot divide by zero.

# %%
try:
    x = int(input())

except ValueError:
    print("Wrong")

else:
    print("Success")
# Out:
# Wrong

# %%
try:
    print("Try")

except:
    print("Except")

else:
    print("Else")

finally:
    print("Finally")
# Out:
# Try
# Else
# Finally

# %% [markdown]
# ## Simple Definition
#
# ### What is overfitting?
# - Model learns noise instead of pattern.
#
# ### What is underfitting?
# - Model is too simple to learn patterns.
#
# ### Bias ex: Underfitting
#
# Bias is the error caused by wrong assumptions in the model. A high bias model is too simple and cannot capture the relationship in data.
#
# Bias হলো model-এর ভুল ধারণার কারণে হওয়া error।
#
# High bias হলে model খুব simple হয় এবং data-এর pattern শিখতে পারে না।
#
# ### Variance ex: Overfitting
#
# Variance is the error caused by the model being too sensitive to training data. A high variance model learns noise instead of the real pattern.
#
# Variance হলো training data-এর উপর model-এর অতিরিক্ত নির্ভরতা।
#
# High variance হলে model training data মুখস্থ করে ফেলে এবং নতুন data-তে ভালো কাজ করে না।
#
#
# `→ High Variance` ## Overfiting
#
#     Train error: Low
#     Test error: High
#
# `→ High Bias` ## Underfitting
#
#     Train error: High
#     Test error: High

# %% [markdown]
# ## What is Regularization?
#
# Regularization is a technique that adds a penalty to the model's loss function to discourage overly complex models and reduce overfitting.
#
# Regularization হলো এমন একটি পদ্ধতি যেখানে Loss Function-এর সাথে অতিরিক্ত penalty যোগ করা হয়, যাতে Model খুব বেশি complex না হয় এবং training data মুখস্থ না করে।
#
# ### Regularization is a technique used to reduce overfitting (high variance).
#
# ### What is the role of alpha?
#
# - alpha controls the strength of regularization. A larger alpha increases the penalty, shrinking more coefficients toward zero.

# %% [markdown]
# ### Precision
#
# - Important when false positives are costly.
#
# Example: Spam detection
#
# ### Recall
#
# - Important when missing positive cases is dangerous.
#
# Example: Cancer detection
#
# ### How to work Logistic Regression internality?
# - Logistic Regression first computes a linear score **($z=wX+b$)**, converts it into a probability using the **Sigmoid function**, measures prediction error with **Binary Cross-Entropy Loss**, and then updates the weights using **Gradient Descent** until the loss is minimized.
